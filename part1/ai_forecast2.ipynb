# %%
from nlp_file_analyser import Analyser

# %%
file_path = 'ai_forecast2.txt'

# %%
analyser = Analyser(file_path)

# %%
analyser.analyse_sentences(do_print=True)
# Out:
# sentence:
# 	The global artificial intelligence market size was $93.5 billion in 2021.
# 		Sentence Parts:
# 			The DET(determiner) det(determiner) size
# 			global ADJ(adjective) amod(adjectival modifier) size
# 			artificial ADJ(adjective) amod(adjectival modifier) size
# 			intelligence NOUN(noun) compound(compound) market
# 			market NOUN(noun) compound(compound) size
# 			size NOUN(noun) nsubj(nominal subject) was
# 			was AUX(auxiliary) ROOT(root) was
# 			$ SYM(symbol) quantmod(modifier of quantifier) billion
# 			93.5 NUM(numeral) compound(compound) billion
# 			billion NUM(numeral) attr(attribute) was
# 			in ADP(adposition) prep(prepositional modifier) was
# 			2021 NUM(numeral) pobj(object of preposition) in
# 			. PUNCT(punctuation) punct(punctuation) was
#
# ====================
#
# sentence:
# 	And according to Grand View Research, Inc., it is projected to expand at a compound annual growth rate (CAGR) of 38.1% from 2022 to 2030.
# 		Sentence Parts:
# 			And CCONJ(coordinating conjunction) cc(coordinating conjunction) projected
# 			according VERB(verb) prep(prepositional modifier) projected
# 			to ADP(adposition) prep(prepositional modifier) according
# 			Grand PROPN(proper noun) compound(compound) Inc.
# 			View PROPN(proper noun) compound(compound) Research
# 			Research PROPN(proper noun) nmod(modifier of nominal) Inc.
# 			, PUNCT(punctuation) punct(punctuation) Research
# 			Inc. PROPN(proper noun) pobj(object of preposition) to
# 			, PUNCT(punctuation) punct(punctuation) projected
# 			it PRON(pronoun) nsubjpass(nominal subject (passive)) projected
# 			is AUX(auxiliary) auxpass(auxiliary (passive)) projected
# 			projected VERB(verb) ROOT(root) projected
# 			to PART(particle) aux(auxiliary) expand
# 			expand VERB(verb) xcomp(open clausal complement) projected
# 			at ADP(adposition) prep(prepositional modifier) expand
# 			a DET(determiner) det(determiner) rate
# 			compound ADJ(adjective) nmod(modifier of nominal) rate
# 			annual ADJ(adjective) amod(adjectival modifier) rate
# 			growth NOUN(noun) compound(compound) rate
# 			rate NOUN(noun) pobj(object of preposition) at
# 			( PUNCT(punctuation) punct(punctuation) rate
# 			CAGR PROPN(proper noun) appos(appositional modifier) rate
# 			) PUNCT(punctuation) punct(punctuation) rate
# 			of ADP(adposition) prep(prepositional modifier) rate
# 			38.1 NUM(numeral) nummod(numeric modifier) %
# 			% NOUN(noun) pobj(object of preposition) of
# 			from ADP(adposition) prep(prepositional modifier) rate
# 			2022 NUM(numeral) pobj(object of preposition) from
# 			to ADP(adposition) prep(prepositional modifier) from
# 			2030 NUM(numeral) pobj(object of preposition) to
# 			. PUNCT(punctuation) punct(punctuation) projected
#
# ====================
#
# sentence:
# 	The market is driven by the increasing number of connected devices, growing demand for personalized services, and a need for real-time solutions.
# 		Sentence Parts:
# 			The DET(determiner) det(determiner) market
# 			market NOUN(noun) nsubjpass(nominal subject (passive)) driven
# 			is AUX(auxiliary) auxpass(auxiliary (passive)) driven
# 			driven VERB(verb) ROOT(root) driven
# 			by ADP(adposition) agent(agent) driven
# 			the DET(determiner) det(determiner) number
# 			increasing VERB(verb) amod(adjectival modifier) number
# 			number NOUN(noun) pobj(object of preposition) by
# 			of ADP(adposition) prep(prepositional modifier) number
# 			connected ADJ(adjective) amod(adjectival modifier) devices
# 			devices NOUN(noun) pobj(object of preposition) of
# 			, PUNCT(punctuation) punct(punctuation) number
# 			growing VERB(verb) amod(adjectival modifier) demand
# 			demand NOUN(noun) appos(appositional modifier) number
# 			for ADP(adposition) prep(prepositional modifier) demand
# 			personalized ADJ(adjective) amod(adjectival modifier) services
# 			services NOUN(noun) pobj(object of preposition) for
# 			, PUNCT(punctuation) punct(punctuation) demand
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) demand
# 			a DET(determiner) det(determiner) need
# 			need NOUN(noun) conj(conjunct) demand
# 			for ADP(adposition) prep(prepositional modifier) need
# 			real ADJ(adjective) amod(adjectival modifier) time
# 			- PUNCT(punctuation) punct(punctuation) time
# 			time NOUN(noun) compound(compound) solutions
# 			solutions NOUN(noun) pobj(object of preposition) for
# 			. PUNCT(punctuation) punct(punctuation) driven
#
# ====================
#
# sentence:
# 	Additionally, advancements in cloud computing technology, along with developments in deep learning algorithms, have increased the adoption rate of AI.
#
#
# 		Sentence Parts:
# 			Additionally ADV(adverb) advmod(adverbial modifier) increased
# 			, PUNCT(punctuation) punct(punctuation) increased
# 			advancements NOUN(noun) nsubj(nominal subject) increased
# 			in ADP(adposition) prep(prepositional modifier) advancements
# 			cloud NOUN(noun) compound(compound) computing
# 			computing PROPN(proper noun) compound(compound) technology
# 			technology NOUN(noun) pobj(object of preposition) in
# 			, PUNCT(punctuation) punct(punctuation) advancements
# 			along ADP(adposition) prep(prepositional modifier) advancements
# 			with ADP(adposition) prep(prepositional modifier) along
# 			developments NOUN(noun) pobj(object of preposition) with
# 			in ADP(adposition) prep(prepositional modifier) developments
# 			deep ADJ(adjective) amod(adjectival modifier) learning
# 			learning NOUN(noun) compound(compound) algorithms
# 			algorithms VERB(verb) pobj(object of preposition) in
# 			, PUNCT(punctuation) punct(punctuation) advancements
# 			have AUX(auxiliary) aux(auxiliary) increased
# 			increased VERB(verb) ROOT(root) increased
# 			the DET(determiner) det(determiner) rate
# 			adoption NOUN(noun) compound(compound) rate
# 			rate NOUN(noun) dobj(direct object) increased
# 			of ADP(adposition) prep(prepositional modifier) rate
# 			AI PROPN(proper noun) pobj(object of preposition) of
# 			. PUNCT(punctuation) punct(punctuation) increased
#
#
#  SPACE(space) dep(unclassified dependent) .
#
# ====================
#
# sentence:
# 	Artificial intelligence growth can be attributed to its widespread application across diverse sectors, including healthcare, retail, and finance.
# 		Sentence Parts:
# 			Artificial ADJ(adjective) amod(adjectival modifier) growth
# 			intelligence NOUN(noun) compound(compound) growth
# 			growth NOUN(noun) nsubjpass(nominal subject (passive)) attributed
# 			can AUX(auxiliary) aux(auxiliary) attributed
# 			be AUX(auxiliary) auxpass(auxiliary (passive)) attributed
# 			attributed VERB(verb) ROOT(root) attributed
# 			to ADP(adposition) prep(prepositional modifier) attributed
# 			its PRON(pronoun) poss(possession modifier) application
# 			widespread ADJ(adjective) amod(adjectival modifier) application
# 			application NOUN(noun) pobj(object of preposition) to
# 			across ADP(adposition) prep(prepositional modifier) application
# 			diverse ADJ(adjective) amod(adjectival modifier) sectors
# 			sectors NOUN(noun) pobj(object of preposition) across
# 			, PUNCT(punctuation) punct(punctuation) application
# 			including VERB(verb) prep(prepositional modifier) application
# 			healthcare NOUN(noun) pobj(object of preposition) including
# 			, PUNCT(punctuation) punct(punctuation) healthcare
# 			retail NOUN(noun) conj(conjunct) healthcare
# 			, PUNCT(punctuation) punct(punctuation) retail
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) retail
# 			finance NOUN(noun) conj(conjunct) retail
# 			. PUNCT(punctuation) punct(punctuation) attributed
#
# ====================
#
# sentence:
# 	However, some challenges must be addressed before it can reach mainstream adoption.
# 		Sentence Parts:
# 			However ADV(adverb) advmod(adverbial modifier) addressed
# 			, PUNCT(punctuation) punct(punctuation) addressed
# 			some DET(determiner) det(determiner) challenges
# 			challenges NOUN(noun) nsubjpass(nominal subject (passive)) addressed
# 			must AUX(auxiliary) aux(auxiliary) addressed
# 			be AUX(auxiliary) auxpass(auxiliary (passive)) addressed
# 			addressed VERB(verb) ROOT(root) addressed
# 			before SCONJ(subordinating conjunction) mark(marker) reach
# 			it PRON(pronoun) nsubj(nominal subject) reach
# 			can AUX(auxiliary) aux(auxiliary) reach
# 			reach VERB(verb) advcl(adverbial clause modifier) addressed
# 			mainstream ADJ(adjective) amod(adjectival modifier) adoption
# 			adoption NOUN(noun) dobj(direct object) reach
# 			. PUNCT(punctuation) punct(punctuation) addressed
#
# ====================
#
# sentence:
# 	These hurdles include high infrastructure costs associated with implementing AI systems and a lack of awareness about these technologies among businesses that could benefit from them.
#
#
# 		Sentence Parts:
# 			These DET(determiner) det(determiner) hurdles
# 			hurdles NOUN(noun) nsubj(nominal subject) include
# 			include VERB(verb) ROOT(root) include
# 			high ADJ(adjective) amod(adjectival modifier) costs
# 			infrastructure NOUN(noun) compound(compound) costs
# 			costs NOUN(noun) dobj(direct object) include
# 			associated VERB(verb) acl(clausal modifier of noun (adjectival clause)) costs
# 			with ADP(adposition) prep(prepositional modifier) associated
# 			implementing VERB(verb) pcomp(complement of preposition) with
# 			AI PROPN(proper noun) compound(compound) systems
# 			systems NOUN(noun) dobj(direct object) implementing
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) systems
# 			a DET(determiner) det(determiner) lack
# 			lack NOUN(noun) conj(conjunct) systems
# 			of ADP(adposition) prep(prepositional modifier) lack
# 			awareness NOUN(noun) pobj(object of preposition) of
# 			about ADP(adposition) prep(prepositional modifier) awareness
# 			these DET(determiner) det(determiner) technologies
# 			technologies NOUN(noun) pobj(object of preposition) about
# 			among ADP(adposition) prep(prepositional modifier) technologies
# 			businesses NOUN(noun) pobj(object of preposition) among
# 			that PRON(pronoun) nsubj(nominal subject) benefit
# 			could AUX(auxiliary) aux(auxiliary) benefit
# 			benefit VERB(verb) relcl(relative clause modifier) businesses
# 			from ADP(adposition) prep(prepositional modifier) benefit
# 			them PRON(pronoun) pobj(object of preposition) from
# 			. PUNCT(punctuation) punct(punctuation) include
#
#
#  SPACE(space) dep(unclassified dependent) .
#
# ====================
#
# sentence:
# 	The artificial intelligence market is segmented based on product type, application, and region.
# 		Sentence Parts:
# 			The DET(determiner) det(determiner) market
# 			artificial ADJ(adjective) amod(adjectival modifier) market
# 			intelligence NOUN(noun) compound(compound) market
# 			market NOUN(noun) nsubjpass(nominal subject (passive)) segmented
# 			is AUX(auxiliary) auxpass(auxiliary (passive)) segmented
# 			segmented VERB(verb) ROOT(root) segmented
# 			based VERB(verb) prep(prepositional modifier) segmented
# 			on ADP(adposition) prep(prepositional modifier) based
# 			product NOUN(noun) compound(compound) type
# 			type NOUN(noun) pobj(object of preposition) on
# 			, PUNCT(punctuation) punct(punctuation) type
# 			application NOUN(noun) conj(conjunct) type
# 			, PUNCT(punctuation) punct(punctuation) application
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) application
# 			region NOUN(noun) conj(conjunct) application
# 			. PUNCT(punctuation) punct(punctuation) segmented
#
# ====================
#
# sentence:
# 	Based on product type, the market has been subdivided into service robots and software.
# 		Sentence Parts:
# 			Based VERB(verb) prep(prepositional modifier) subdivided
# 			on ADP(adposition) prep(prepositional modifier) Based
# 			product NOUN(noun) compound(compound) type
# 			type NOUN(noun) pobj(object of preposition) on
# 			, PUNCT(punctuation) punct(punctuation) subdivided
# 			the DET(determiner) det(determiner) market
# 			market NOUN(noun) nsubjpass(nominal subject (passive)) subdivided
# 			has AUX(auxiliary) aux(auxiliary) subdivided
# 			been AUX(auxiliary) auxpass(auxiliary (passive)) subdivided
# 			subdivided VERB(verb) ROOT(root) subdivided
# 			into ADP(adposition) prep(prepositional modifier) subdivided
# 			service NOUN(noun) compound(compound) robots
# 			robots NOUN(noun) pobj(object of preposition) into
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) robots
# 			software NOUN(noun) conj(conjunct) robots
# 			. PUNCT(punctuation) punct(punctuation) subdivided
#
# ====================
#
# sentence:
# 	The services portion accounted for around 66% share in 2016.
# 		Sentence Parts:
# 			The DET(determiner) det(determiner) portion
# 			services NOUN(noun) compound(compound) portion
# 			portion NOUN(noun) nsubj(nominal subject) accounted
# 			accounted VERB(verb) ROOT(root) accounted
# 			for ADP(adposition) prep(prepositional modifier) accounted
# 			around ADP(adposition) quantmod(modifier of quantifier) 66
# 			66 NUM(numeral) nummod(numeric modifier) %
# 			% NOUN(noun) compound(compound) share
# 			share NOUN(noun) pobj(object of preposition) for
# 			in ADP(adposition) prep(prepositional modifier) accounted
# 			2016 NUM(numeral) pobj(object of preposition) in
# 			. PUNCT(punctuation) punct(punctuation) accounted
#
# ====================
#
# sentence:
# 	Based on application, AI has segmented into healthcare and life sciences; manufacturing and logistics; energy and utilities; banking, financial services, and insurance (BFSI); process manufacturing industries; retail and eCommerce; and agriculture and forestry sectors (agribusinesses).
#
#
# 		Sentence Parts:
# 			Based VERB(verb) prep(prepositional modifier) segmented
# 			on ADP(adposition) prep(prepositional modifier) Based
# 			application NOUN(noun) pobj(object of preposition) on
# 			, PUNCT(punctuation) punct(punctuation) segmented
# 			AI PROPN(proper noun) nsubj(nominal subject) segmented
# 			has AUX(auxiliary) aux(auxiliary) segmented
# 			segmented VERB(verb) ROOT(root) segmented
# 			into ADP(adposition) prep(prepositional modifier) segmented
# 			healthcare NOUN(noun) nmod(modifier of nominal) sciences
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) healthcare
# 			life NOUN(noun) conj(conjunct) healthcare
# 			sciences NOUN(noun) pobj(object of preposition) into
# 			; PUNCT(punctuation) punct(punctuation) sciences
# 			manufacturing NOUN(noun) conj(conjunct) sciences
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) manufacturing
# 			logistics NOUN(noun) conj(conjunct) manufacturing
# 			; PUNCT(punctuation) punct(punctuation) manufacturing
# 			energy NOUN(noun) conj(conjunct) manufacturing
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) energy
# 			utilities NOUN(noun) conj(conjunct) energy
# 			; PUNCT(punctuation) punct(punctuation) energy
# 			banking NOUN(noun) conj(conjunct) energy
# 			, PUNCT(punctuation) punct(punctuation) banking
# 			financial ADJ(adjective) amod(adjectival modifier) services
# 			services NOUN(noun) conj(conjunct) banking
# 			, PUNCT(punctuation) punct(punctuation) services
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) services
# 			insurance NOUN(noun) conj(conjunct) services
# 			( PUNCT(punctuation) punct(punctuation) insurance
# 			BFSI PROPN(proper noun) appos(appositional modifier) insurance
# 			) PUNCT(punctuation) punct(punctuation) insurance
# 			; PUNCT(punctuation) punct(punctuation) segmented
# 			process NOUN(noun) compound(compound) manufacturing
# 			manufacturing NOUN(noun) compound(compound) industries
# 			industries NOUN(noun) dobj(direct object) segmented
# 			; PUNCT(punctuation) punct(punctuation) industries
# 			retail NOUN(noun) conj(conjunct) industries
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) retail
# 			eCommerce PROPN(proper noun) conj(conjunct) retail
# 			; PUNCT(punctuation) punct(punctuation) retail
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) retail
# 			agriculture NOUN(noun) nmod(modifier of nominal) sectors
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) agriculture
# 			forestry NOUN(noun) conj(conjunct) agriculture
# 			sectors NOUN(noun) conj(conjunct) retail
# 			( PUNCT(punctuation) punct(punctuation) sectors
# 			agribusinesses NOUN(noun) appos(appositional modifier) sectors
# 			) PUNCT(punctuation) punct(punctuation) segmented
# 			. PUNCT(punctuation) punct(punctuation) segmented
#
#
#  SPACE(space) dep(unclassified dependent) .
#
# ====================
#
# sentence:
# 	The healthcare sector holds significant potential for AI across various applications.
# 		Sentence Parts:
# 			The DET(determiner) det(determiner) sector
# 			healthcare NOUN(noun) compound(compound) sector
# 			sector NOUN(noun) nsubj(nominal subject) holds
# 			holds VERB(verb) ROOT(root) holds
# 			significant ADJ(adjective) amod(adjectival modifier) potential
# 			potential NOUN(noun) dobj(direct object) holds
# 			for ADP(adposition) prep(prepositional modifier) potential
# 			AI PROPN(proper noun) pobj(object of preposition) for
# 			across ADP(adposition) prep(prepositional modifier) potential
# 			various ADJ(adjective) amod(adjectival modifier) applications
# 			applications NOUN(noun) pobj(object of preposition) across
# 			. PUNCT(punctuation) punct(punctuation) holds
#
# ====================
#
# sentence:
# 	This includes medical imaging analysis, molecular biology research, and drug discovery.
# 		Sentence Parts:
# 			This PRON(pronoun) nsubj(nominal subject) includes
# 			includes VERB(verb) ROOT(root) includes
# 			medical ADJ(adjective) amod(adjectival modifier) imaging
# 			imaging NOUN(noun) compound(compound) analysis
# 			analysis NOUN(noun) dobj(direct object) includes
# 			, PUNCT(punctuation) punct(punctuation) analysis
# 			molecular ADJ(adjective) amod(adjectival modifier) research
# 			biology NOUN(noun) compound(compound) research
# 			research NOUN(noun) conj(conjunct) analysis
# 			, PUNCT(punctuation) punct(punctuation) research
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) research
# 			drug NOUN(noun) compound(compound) discovery
# 			discovery NOUN(noun) conj(conjunct) research
# 			. PUNCT(punctuation) punct(punctuation) includes
#
# ====================
#
# sentence:
# 	Additionally, there are developments in drug optimization through predictive analytics tools provided by leading players, such as NVIDIA Corporation (NVDA), Intel Corporation (INTC), Alphabet Inc. (GOOGL), and Amazon Web Services Inc. (AMZN).
# 		Sentence Parts:
# 			Additionally ADV(adverb) advmod(adverbial modifier) are
# 			, PUNCT(punctuation) punct(punctuation) are
# 			there PRON(pronoun) expl(expletive) are
# 			are VERB(verb) ROOT(root) are
# 			developments NOUN(noun) attr(attribute) are
# 			in ADP(adposition) prep(prepositional modifier) developments
# 			drug NOUN(noun) compound(compound) optimization
# 			optimization NOUN(noun) pobj(object of preposition) in
# 			through ADP(adposition) prep(prepositional modifier) developments
# 			predictive ADJ(adjective) amod(adjectival modifier) tools
# 			analytics NOUN(noun) compound(compound) tools
# 			tools NOUN(noun) pobj(object of preposition) through
# 			provided VERB(verb) acl(clausal modifier of noun (adjectival clause)) tools
# 			by ADP(adposition) agent(agent) provided
# 			leading VERB(verb) amod(adjectival modifier) players
# 			players NOUN(noun) pobj(object of preposition) by
# 			, PUNCT(punctuation) punct(punctuation) players
# 			such ADJ(adjective) amod(adjectival modifier) as
# 			as ADP(adposition) prep(prepositional modifier) players
# 			NVIDIA PROPN(proper noun) compound(compound) Corporation
# 			Corporation PROPN(proper noun) pobj(object of preposition) as
# 			( PUNCT(punctuation) punct(punctuation) Corporation
# 			NVDA PROPN(proper noun) appos(appositional modifier) Corporation
# 			) PUNCT(punctuation) punct(punctuation) Corporation
# 			, PUNCT(punctuation) punct(punctuation) Corporation
# 			Intel PROPN(proper noun) compound(compound) Corporation
# 			Corporation PROPN(proper noun) conj(conjunct) Corporation
# 			( PUNCT(punctuation) punct(punctuation) Corporation
# 			INTC PROPN(proper noun) npadvmod(noun phrase as adverbial modifier) Corporation
# 			) PUNCT(punctuation) punct(punctuation) Corporation
# 			, PUNCT(punctuation) punct(punctuation) Corporation
# 			Alphabet PROPN(proper noun) compound(compound) Inc.
# 			Inc. PROPN(proper noun) conj(conjunct) Corporation
# 			( PUNCT(punctuation) punct(punctuation) Inc.
# 			GOOGL PROPN(proper noun) appos(appositional modifier) Inc.
# 			) PUNCT(punctuation) punct(punctuation) Corporation
# 			, PUNCT(punctuation) punct(punctuation) Corporation
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) Corporation
# 			Amazon PROPN(proper noun) compound(compound) Inc.
# 			Web PROPN(proper noun) compound(compound) Inc.
# 			Services PROPN(proper noun) compound(compound) Inc.
# 			Inc. PROPN(proper noun) conj(conjunct) Corporation
# 			( PUNCT(punctuation) punct(punctuation) Inc.
# 			AMZN PROPN(proper noun) appos(appositional modifier) Inc.
# 			) PUNCT(punctuation) punct(punctuation) Inc.
# 			. PUNCT(punctuation) punct(punctuation) are
#
# ====================
#
# sentence:
# 	This is primarily due to their high adoption rate among researchers worldwide coupled with increasing demand from patients willing to pay extra if provided better care due to side effects associated with traditional treatment methods.
#
# 		Sentence Parts:
# 			This PRON(pronoun) nsubj(nominal subject) is
# 			is AUX(auxiliary) ROOT(root) is
# 			primarily ADV(adverb) advmod(adverbial modifier) is
# 			due ADJ(adjective) prep(prepositional modifier) is
# 			to ADP(adposition) pcomp(complement of preposition) due
# 			their PRON(pronoun) poss(possession modifier) rate
# 			high ADJ(adjective) amod(adjectival modifier) rate
# 			adoption NOUN(noun) compound(compound) rate
# 			rate NOUN(noun) pobj(object of preposition) due
# 			among ADP(adposition) prep(prepositional modifier) rate
# 			researchers NOUN(noun) pobj(object of preposition) among
# 			worldwide ADV(adverb) advmod(adverbial modifier) researchers
# 			coupled VERB(verb) acl(clausal modifier of noun (adjectival clause)) researchers
# 			with ADP(adposition) prep(prepositional modifier) coupled
# 			increasing VERB(verb) amod(adjectival modifier) demand
# 			demand NOUN(noun) pobj(object of preposition) with
# 			from ADP(adposition) prep(prepositional modifier) demand
# 			patients NOUN(noun) pobj(object of preposition) from
# 			willing ADJ(adjective) amod(adjectival modifier) patients
# 			to PART(particle) aux(auxiliary) pay
# 			pay VERB(verb) xcomp(open clausal complement) willing
# 			extra ADJ(adjective) dobj(direct object) pay
# 			if SCONJ(subordinating conjunction) mark(marker) provided
# 			provided VERB(verb) advcl(adverbial clause modifier) is
# 			better ADJ(adjective) amod(adjectival modifier) care
# 			care NOUN(noun) dobj(direct object) provided
# 			due ADP(adposition) prep(prepositional modifier) provided
# 			to ADP(adposition) pcomp(complement of preposition) due
# 			side NOUN(noun) compound(compound) effects
# 			effects NOUN(noun) pobj(object of preposition) to
# 			associated VERB(verb) acl(clausal modifier of noun (adjectival clause)) effects
# 			with ADP(adposition) prep(prepositional modifier) associated
# 			traditional ADJ(adjective) amod(adjectival modifier) methods
# 			treatment NOUN(noun) compound(compound) methods
# 			methods NOUN(noun) pobj(object of preposition) with
# 			. PUNCT(punctuation) punct(punctuation) is
#
#  SPACE(space) dep(unclassified dependent) .
#
# ====================
#
# sentence:
# 	Artificial Intelligence Market by Component Analysis
#
# AI market analysis can be segmented into hardware, software, and service components.
# 		Sentence Parts:
# 			Artificial PROPN(proper noun) compound(compound) Market
# 			Intelligence PROPN(proper noun) compound(compound) Market
# 			Market PROPN(proper noun) nsubjpass(nominal subject (passive)) segmented
# 			by ADP(adposition) prep(prepositional modifier) Market
# 			Component PROPN(proper noun) compound(compound) Analysis
# 			Analysis PROPN(proper noun) compound(compound) AI
#
#
#  SPACE(space) dep(unclassified dependent) Analysis
# 			AI PROPN(proper noun) compound(compound) analysis
# 			market NOUN(noun) compound(compound) analysis
# 			analysis NOUN(noun) pobj(object of preposition) by
# 			can AUX(auxiliary) aux(auxiliary) segmented
# 			be AUX(auxiliary) auxpass(auxiliary (passive)) segmented
# 			segmented VERB(verb) ROOT(root) segmented
# 			into ADP(adposition) prep(prepositional modifier) segmented
# 			hardware NOUN(noun) pobj(object of preposition) into
# 			, PUNCT(punctuation) punct(punctuation) hardware
# 			software NOUN(noun) conj(conjunct) hardware
# 			, PUNCT(punctuation) punct(punctuation) software
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) software
# 			service NOUN(noun) compound(compound) components
# 			components NOUN(noun) conj(conjunct) software
# 			. PUNCT(punctuation) punct(punctuation) segmented
#
# ====================
#
# sentence:
# 	The hardware segment is expected to grow at the highest CAGR during the forecast period.
# 		Sentence Parts:
# 			The DET(determiner) det(determiner) segment
# 			hardware NOUN(noun) compound(compound) segment
# 			segment NOUN(noun) nsubjpass(nominal subject (passive)) expected
# 			is AUX(auxiliary) auxpass(auxiliary (passive)) expected
# 			expected VERB(verb) ROOT(root) expected
# 			to PART(particle) aux(auxiliary) grow
# 			grow VERB(verb) xcomp(open clausal complement) expected
# 			at ADP(adposition) prep(prepositional modifier) grow
# 			the DET(determiner) det(determiner) CAGR
# 			highest ADJ(adjective) amod(adjectival modifier) CAGR
# 			CAGR PROPN(proper noun) pobj(object of preposition) at
# 			during ADP(adposition) prep(prepositional modifier) grow
# 			the DET(determiner) det(determiner) period
# 			forecast NOUN(noun) compound(compound) period
# 			period NOUN(noun) pobj(object of preposition) during
# 			. PUNCT(punctuation) punct(punctuation) expected
#
# ====================
#
# sentence:
# 	The need for AI services is projected to rise as smart solutions such as virtual assistants and personalized online experiences become more widely used.
# 		Sentence Parts:
# 			The DET(determiner) det(determiner) need
# 			need NOUN(noun) nsubjpass(nominal subject (passive)) projected
# 			for ADP(adposition) prep(prepositional modifier) need
# 			AI PROPN(proper noun) compound(compound) services
# 			services NOUN(noun) pobj(object of preposition) for
# 			is AUX(auxiliary) auxpass(auxiliary (passive)) projected
# 			projected VERB(verb) ROOT(root) projected
# 			to PART(particle) aux(auxiliary) rise
# 			rise VERB(verb) xcomp(open clausal complement) projected
# 			as ADP(adposition) prep(prepositional modifier) rise
# 			smart ADJ(adjective) amod(adjectival modifier) solutions
# 			solutions NOUN(noun) pobj(object of preposition) as
# 			such ADJ(adjective) amod(adjectival modifier) as
# 			as ADP(adposition) prep(prepositional modifier) solutions
# 			virtual ADJ(adjective) amod(adjectival modifier) assistants
# 			assistants NOUN(noun) pobj(object of preposition) as
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) rise
# 			personalized VERB(verb) amod(adjectival modifier) experiences
# 			online ADJ(adjective) amod(adjectival modifier) experiences
# 			experiences NOUN(noun) nsubj(nominal subject) become
# 			become VERB(verb) conj(conjunct) rise
# 			more ADV(adverb) advmod(adverbial modifier) widely
# 			widely ADV(adverb) advmod(adverbial modifier) used
# 			used VERB(verb) acomp(adjectival complement) become
# 			. PUNCT(punctuation) punct(punctuation) projected
#
# ====================
#
# sentence:
# 	These services use AI capabilities to improve business operations, such as creating automated and accurate sales projections based on client interactions and sales data.
#
# 		Sentence Parts:
# 			These DET(determiner) det(determiner) services
# 			services NOUN(noun) nsubj(nominal subject) use
# 			use VERB(verb) ROOT(root) use
# 			AI PROPN(proper noun) compound(compound) capabilities
# 			capabilities NOUN(noun) dobj(direct object) use
# 			to PART(particle) aux(auxiliary) improve
# 			improve VERB(verb) xcomp(open clausal complement) use
# 			business NOUN(noun) compound(compound) operations
# 			operations NOUN(noun) dobj(direct object) improve
# 			, PUNCT(punctuation) punct(punctuation) operations
# 			such ADJ(adjective) amod(adjectival modifier) as
# 			as ADP(adposition) prep(prepositional modifier) operations
# 			creating VERB(verb) pcomp(complement of preposition) as
# 			automated VERB(verb) amod(adjectival modifier) projections
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) automated
# 			accurate ADJ(adjective) conj(conjunct) automated
# 			sales NOUN(noun) compound(compound) projections
# 			projections NOUN(noun) dobj(direct object) creating
# 			based VERB(verb) acl(clausal modifier of noun (adjectival clause)) projections
# 			on ADP(adposition) prep(prepositional modifier) based
# 			client NOUN(noun) compound(compound) interactions
# 			interactions NOUN(noun) pobj(object of preposition) on
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) interactions
# 			sales NOUN(noun) compound(compound) data
# 			data NOUN(noun) conj(conjunct) interactions
# 			. PUNCT(punctuation) punct(punctuation) use
#
#  SPACE(space) dep(unclassified dependent) .
#
# ====================
#
# sentence:
# 	Artificial Intelligence Market by Technology
#
# There are many different types of artificial intelligence, so it can be difficult to understand the market without an overview of the technology.
# 		Sentence Parts:
# 			Artificial PROPN(proper noun) compound(compound) Market
# 			Intelligence PROPN(proper noun) compound(compound) Market
# 			Market PROPN(proper noun) nsubj(nominal subject) are
# 			by ADP(adposition) prep(prepositional modifier) Market
# 			Technology PROPN(proper noun) pobj(object of preposition) by
#
#
#  SPACE(space) dep(unclassified dependent) Technology
# 			There PRON(pronoun) expl(expletive) are
# 			are VERB(verb) ROOT(root) are
# 			many ADJ(adjective) amod(adjectival modifier) types
# 			different ADJ(adjective) amod(adjectival modifier) types
# 			types NOUN(noun) attr(attribute) are
# 			of ADP(adposition) prep(prepositional modifier) types
# 			artificial ADJ(adjective) amod(adjectival modifier) intelligence
# 			intelligence NOUN(noun) pobj(object of preposition) of
# 			, PUNCT(punctuation) punct(punctuation) are
# 			so SCONJ(subordinating conjunction) mark(marker) be
# 			it PRON(pronoun) nsubj(nominal subject) be
# 			can AUX(auxiliary) aux(auxiliary) be
# 			be AUX(auxiliary) conj(conjunct) are
# 			difficult ADJ(adjective) acomp(adjectival complement) be
# 			to PART(particle) aux(auxiliary) understand
# 			understand VERB(verb) xcomp(open clausal complement) be
# 			the DET(determiner) det(determiner) market
# 			market NOUN(noun) dobj(direct object) understand
# 			without ADP(adposition) prep(prepositional modifier) understand
# 			an DET(determiner) det(determiner) overview
# 			overview NOUN(noun) pobj(object of preposition) without
# 			of ADP(adposition) prep(prepositional modifier) overview
# 			the DET(determiner) det(determiner) technology
# 			technology NOUN(noun) pobj(object of preposition) of
# 			. PUNCT(punctuation) punct(punctuation) are
#
# ====================
#
# sentence:
# 	The AI market is further segmented by technology.
# 		Sentence Parts:
# 			The DET(determiner) det(determiner) market
# 			AI PROPN(proper noun) compound(compound) market
# 			market NOUN(noun) nsubjpass(nominal subject (passive)) segmented
# 			is AUX(auxiliary) auxpass(auxiliary (passive)) segmented
# 			further ADV(adverb) advmod(adverbial modifier) segmented
# 			segmented VERB(verb) ROOT(root) segmented
# 			by ADP(adposition) agent(agent) segmented
# 			technology NOUN(noun) pobj(object of preposition) by
# 			. PUNCT(punctuation) punct(punctuation) segmented
#
# ====================
#
# sentence:
# 	Natural language processing (NLP), machine learning, context-aware computing, computer vision, and virtual agents are some major technologies used in the AI market.
#
#
# 		Sentence Parts:
# 			Natural ADJ(adjective) amod(adjectival modifier) language
# 			language NOUN(noun) compound(compound) processing
# 			processing NOUN(noun) nsubj(nominal subject) are
# 			( PUNCT(punctuation) punct(punctuation) processing
# 			NLP PROPN(proper noun) appos(appositional modifier) processing
# 			) PUNCT(punctuation) punct(punctuation) processing
# 			, PUNCT(punctuation) punct(punctuation) processing
# 			machine NOUN(noun) compound(compound) learning
# 			learning NOUN(noun) conj(conjunct) processing
# 			, PUNCT(punctuation) punct(punctuation) learning
# 			context NOUN(noun) npadvmod(noun phrase as adverbial modifier) aware
# 			- PUNCT(punctuation) punct(punctuation) aware
# 			aware ADJ(adjective) amod(adjectival modifier) computing
# 			computing NOUN(noun) conj(conjunct) learning
# 			, PUNCT(punctuation) punct(punctuation) computing
# 			computer NOUN(noun) compound(compound) vision
# 			vision NOUN(noun) conj(conjunct) computing
# 			, PUNCT(punctuation) punct(punctuation) vision
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) vision
# 			virtual ADJ(adjective) amod(adjectival modifier) agents
# 			agents NOUN(noun) conj(conjunct) vision
# 			are AUX(auxiliary) ROOT(root) are
# 			some DET(determiner) det(determiner) technologies
# 			major ADJ(adjective) amod(adjectival modifier) technologies
# 			technologies NOUN(noun) attr(attribute) are
# 			used VERB(verb) acl(clausal modifier of noun (adjectival clause)) technologies
# 			in ADP(adposition) prep(prepositional modifier) used
# 			the DET(determiner) det(determiner) market
# 			AI PROPN(proper noun) compound(compound) market
# 			market NOUN(noun) pobj(object of preposition) in
# 			. PUNCT(punctuation) punct(punctuation) are
#
#
#  SPACE(space) dep(unclassified dependent) .
#
# ====================
#
# sentence:
# 	NLP enables a system to understand human language through various methods like speech recognition and natural language understanding.
# 		Sentence Parts:
# 			NLP PROPN(proper noun) nsubj(nominal subject) enables
# 			enables VERB(verb) ROOT(root) enables
# 			a DET(determiner) det(determiner) system
# 			system NOUN(noun) dobj(direct object) enables
# 			to PART(particle) aux(auxiliary) understand
# 			understand VERB(verb) relcl(relative clause modifier) system
# 			human ADJ(adjective) amod(adjectival modifier) language
# 			language NOUN(noun) dobj(direct object) understand
# 			through ADP(adposition) prep(prepositional modifier) understand
# 			various ADJ(adjective) amod(adjectival modifier) methods
# 			methods NOUN(noun) pobj(object of preposition) through
# 			like ADP(adposition) prep(prepositional modifier) methods
# 			speech NOUN(noun) compound(compound) recognition
# 			recognition NOUN(noun) pobj(object of preposition) like
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) recognition
# 			natural ADJ(adjective) amod(adjectival modifier) language
# 			language NOUN(noun) compound(compound) understanding
# 			understanding NOUN(noun) conj(conjunct) recognition
# 			. PUNCT(punctuation) punct(punctuation) enables
#
# ====================
#
# sentence:
# 	Machine learning refers to the process of developing an algorithm that can automatically learn from its experience without being explicitly programmed.
# 		Sentence Parts:
# 			Machine NOUN(noun) compound(compound) learning
# 			learning NOUN(noun) nsubj(nominal subject) refers
# 			refers VERB(verb) ROOT(root) refers
# 			to ADP(adposition) prep(prepositional modifier) refers
# 			the DET(determiner) det(determiner) process
# 			process NOUN(noun) pobj(object of preposition) to
# 			of ADP(adposition) prep(prepositional modifier) process
# 			developing VERB(verb) pcomp(complement of preposition) of
# 			an DET(determiner) det(determiner) algorithm
# 			algorithm NOUN(noun) dobj(direct object) developing
# 			that PRON(pronoun) nsubj(nominal subject) learn
# 			can AUX(auxiliary) aux(auxiliary) learn
# 			automatically ADV(adverb) advmod(adverbial modifier) learn
# 			learn VERB(verb) relcl(relative clause modifier) algorithm
# 			from ADP(adposition) prep(prepositional modifier) learn
# 			its PRON(pronoun) poss(possession modifier) experience
# 			experience NOUN(noun) pobj(object of preposition) from
# 			without ADP(adposition) prep(prepositional modifier) learn
# 			being AUX(auxiliary) auxpass(auxiliary (passive)) programmed
# 			explicitly ADV(adverb) advmod(adverbial modifier) programmed
# 			programmed VERB(verb) pcomp(complement of preposition) without
# 			. PUNCT(punctuation) punct(punctuation) refers
#
# ====================
#
# sentence:
# 	Context-aware computing refers to systems that adapt their behavior according to their surroundings or environment, such as GPS location services on smartphones or self-driving cars.
#
#
# 		Sentence Parts:
# 			Context NOUN(noun) npadvmod(noun phrase as adverbial modifier) aware
# 			- PUNCT(punctuation) punct(punctuation) aware
# 			aware ADJ(adjective) amod(adjectival modifier) computing
# 			computing NOUN(noun) nsubj(nominal subject) refers
# 			refers VERB(verb) ROOT(root) refers
# 			to ADP(adposition) prep(prepositional modifier) refers
# 			systems NOUN(noun) pobj(object of preposition) to
# 			that PRON(pronoun) nsubj(nominal subject) adapt
# 			adapt VERB(verb) relcl(relative clause modifier) systems
# 			their PRON(pronoun) poss(possession modifier) behavior
# 			behavior NOUN(noun) dobj(direct object) adapt
# 			according VERB(verb) prep(prepositional modifier) adapt
# 			to ADP(adposition) prep(prepositional modifier) according
# 			their PRON(pronoun) poss(possession modifier) surroundings
# 			surroundings NOUN(noun) pobj(object of preposition) to
# 			or CCONJ(coordinating conjunction) cc(coordinating conjunction) surroundings
# 			environment NOUN(noun) conj(conjunct) surroundings
# 			, PUNCT(punctuation) punct(punctuation) surroundings
# 			such ADJ(adjective) amod(adjectival modifier) as
# 			as ADP(adposition) prep(prepositional modifier) surroundings
# 			GPS PROPN(proper noun) compound(compound) location
# 			location NOUN(noun) compound(compound) services
# 			services NOUN(noun) pobj(object of preposition) as
# 			on ADP(adposition) prep(prepositional modifier) services
# 			smartphones NOUN(noun) pobj(object of preposition) on
# 			or CCONJ(coordinating conjunction) cc(coordinating conjunction) smartphones
# 			self NOUN(noun) npadvmod(noun phrase as adverbial modifier) driving
# 			- PUNCT(punctuation) punct(punctuation) driving
# 			driving VERB(verb) amod(adjectival modifier) cars
# 			cars NOUN(noun) conj(conjunct) smartphones
# 			. PUNCT(punctuation) punct(punctuation) refers
#
#
#  SPACE(space) dep(unclassified dependent) .
#
# ====================
#
# sentence:
# 	Computer vision refers to techniques used to process images for perception tasks, such as facial recognition, which plays a role in self-driving cars that can detect pedestrians at night in low visibility conditions.
#
# 		Sentence Parts:
# 			Computer NOUN(noun) compound(compound) vision
# 			vision NOUN(noun) nsubj(nominal subject) refers
# 			refers VERB(verb) ROOT(root) refers
# 			to ADP(adposition) prep(prepositional modifier) refers
# 			techniques NOUN(noun) pobj(object of preposition) to
# 			used VERB(verb) acl(clausal modifier of noun (adjectival clause)) techniques
# 			to PART(particle) aux(auxiliary) process
# 			process VERB(verb) xcomp(open clausal complement) used
# 			images NOUN(noun) dobj(direct object) process
# 			for ADP(adposition) prep(prepositional modifier) images
# 			perception NOUN(noun) compound(compound) tasks
# 			tasks NOUN(noun) pobj(object of preposition) for
# 			, PUNCT(punctuation) punct(punctuation) tasks
# 			such ADJ(adjective) amod(adjectival modifier) as
# 			as ADP(adposition) prep(prepositional modifier) tasks
# 			facial ADJ(adjective) amod(adjectival modifier) recognition
# 			recognition NOUN(noun) pobj(object of preposition) as
# 			, PUNCT(punctuation) punct(punctuation) recognition
# 			which PRON(pronoun) nsubj(nominal subject) plays
# 			plays VERB(verb) relcl(relative clause modifier) recognition
# 			a DET(determiner) det(determiner) role
# 			role NOUN(noun) dobj(direct object) plays
# 			in ADP(adposition) prep(prepositional modifier) role
# 			self NOUN(noun) npadvmod(noun phrase as adverbial modifier) driving
# 			- PUNCT(punctuation) punct(punctuation) driving
# 			driving VERB(verb) amod(adjectival modifier) cars
# 			cars NOUN(noun) pobj(object of preposition) in
# 			that PRON(pronoun) nsubj(nominal subject) detect
# 			can AUX(auxiliary) aux(auxiliary) detect
# 			detect VERB(verb) relcl(relative clause modifier) cars
# 			pedestrians NOUN(noun) dobj(direct object) detect
# 			at ADP(adposition) prep(prepositional modifier) detect
# 			night NOUN(noun) pobj(object of preposition) at
# 			in ADP(adposition) prep(prepositional modifier) detect
# 			low ADJ(adjective) amod(adjectival modifier) conditions
# 			visibility NOUN(noun) compound(compound) conditions
# 			conditions NOUN(noun) pobj(object of preposition) in
# 			. PUNCT(punctuation) punct(punctuation) refers
#
#  SPACE(space) dep(unclassified dependent) .
#
# ====================
#
# sentence:
# 	Artificial Intelligence Market by End-User Industry
#
# The AI market is segmented by end-user industry into retail, healthcare and life sciences, automotive and transportation, BFSI, consumer goods and retail, manufacturing, media and entertainment, agriculture and food, and energy and utilities.
#
#
# 		Sentence Parts:
# 			Artificial PROPN(proper noun) compound(compound) Market
# 			Intelligence PROPN(proper noun) compound(compound) Market
# 			Market PROPN(proper noun) nsubjpass(nominal subject (passive)) segmented
# 			by ADP(adposition) prep(prepositional modifier) Market
# 			End PROPN(proper noun) compound(compound) User
# 			- PUNCT(punctuation) punct(punctuation) User
# 			User PROPN(proper noun) compound(compound) Industry
# 			Industry PROPN(proper noun) pobj(object of preposition) by
#
#
#  SPACE(space) dep(unclassified dependent) Industry
# 			The DET(determiner) det(determiner) market
# 			AI PROPN(proper noun) compound(compound) market
# 			market NOUN(noun) pobj(object of preposition) by
# 			is AUX(auxiliary) auxpass(auxiliary (passive)) segmented
# 			segmented VERB(verb) ROOT(root) segmented
# 			by ADP(adposition) agent(agent) segmented
# 			end NOUN(noun) compound(compound) user
# 			- PUNCT(punctuation) punct(punctuation) user
# 			user NOUN(noun) compound(compound) industry
# 			industry NOUN(noun) pobj(object of preposition) by
# 			into ADP(adposition) prep(prepositional modifier) segmented
# 			retail NOUN(noun) pobj(object of preposition) into
# 			, PUNCT(punctuation) punct(punctuation) retail
# 			healthcare NOUN(noun) conj(conjunct) retail
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) healthcare
# 			life NOUN(noun) conj(conjunct) healthcare
# 			sciences NOUN(noun) conj(conjunct) healthcare
# 			, PUNCT(punctuation) punct(punctuation) sciences
# 			automotive ADJ(adjective) conj(conjunct) sciences
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) automotive
# 			transportation NOUN(noun) conj(conjunct) automotive
# 			, PUNCT(punctuation) punct(punctuation) automotive
# 			BFSI PROPN(proper noun) conj(conjunct) retail
# 			, PUNCT(punctuation) punct(punctuation) BFSI
# 			consumer NOUN(noun) compound(compound) goods
# 			goods NOUN(noun) conj(conjunct) BFSI
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) goods
# 			retail NOUN(noun) conj(conjunct) goods
# 			, PUNCT(punctuation) punct(punctuation) retail
# 			manufacturing NOUN(noun) conj(conjunct) retail
# 			, PUNCT(punctuation) punct(punctuation) manufacturing
# 			media NOUN(noun) conj(conjunct) manufacturing
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) media
# 			entertainment NOUN(noun) conj(conjunct) media
# 			, PUNCT(punctuation) punct(punctuation) entertainment
# 			agriculture NOUN(noun) conj(conjunct) entertainment
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) agriculture
# 			food NOUN(noun) conj(conjunct) agriculture
# 			, PUNCT(punctuation) punct(punctuation) agriculture
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) agriculture
# 			energy NOUN(noun) conj(conjunct) agriculture
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) energy
# 			utilities NOUN(noun) conj(conjunct) energy
# 			. PUNCT(punctuation) punct(punctuation) segmented
#
#
#  SPACE(space) dep(unclassified dependent) .
#
# ====================
#
# sentence:
# 	The retail sector accounted for one of the largest shares of the AI market in 2020.
# 		Sentence Parts:
# 			The DET(determiner) det(determiner) sector
# 			retail ADJ(adjective) amod(adjectival modifier) sector
# 			sector NOUN(noun) nsubj(nominal subject) accounted
# 			accounted VERB(verb) ROOT(root) accounted
# 			for ADP(adposition) prep(prepositional modifier) accounted
# 			one NUM(numeral) pobj(object of preposition) for
# 			of ADP(adposition) prep(prepositional modifier) one
# 			the DET(determiner) det(determiner) shares
# 			largest ADJ(adjective) amod(adjectival modifier) shares
# 			shares NOUN(noun) pobj(object of preposition) of
# 			of ADP(adposition) prep(prepositional modifier) shares
# 			the DET(determiner) det(determiner) market
# 			AI PROPN(proper noun) compound(compound) market
# 			market NOUN(noun) pobj(object of preposition) of
# 			in ADP(adposition) prep(prepositional modifier) accounted
# 			2020 NUM(numeral) pobj(object of preposition) in
# 			. PUNCT(punctuation) punct(punctuation) accounted
#
# ====================
#
# sentence:
# 	This can be attributed to the rise in smartphone usage across the globe, as well as an increase in the use of smart devices.
# 		Sentence Parts:
# 			This PRON(pronoun) nsubjpass(nominal subject (passive)) attributed
# 			can AUX(auxiliary) aux(auxiliary) attributed
# 			be AUX(auxiliary) auxpass(auxiliary (passive)) attributed
# 			attributed VERB(verb) ROOT(root) attributed
# 			to ADP(adposition) prep(prepositional modifier) attributed
# 			the DET(determiner) det(determiner) rise
# 			rise NOUN(noun) pobj(object of preposition) to
# 			in ADP(adposition) prep(prepositional modifier) rise
# 			smartphone NOUN(noun) compound(compound) usage
# 			usage NOUN(noun) pobj(object of preposition) in
# 			across ADP(adposition) prep(prepositional modifier) rise
# 			the DET(determiner) det(determiner) globe
# 			globe NOUN(noun) pobj(object of preposition) across
# 			, PUNCT(punctuation) punct(punctuation) attributed
# 			as ADV(adverb) advmod(adverbial modifier) as
# 			well ADV(adverb) advmod(adverbial modifier) as
# 			as ADP(adposition) cc(coordinating conjunction) attributed
# 			an DET(determiner) det(determiner) increase
# 			increase NOUN(noun) conj(conjunct) attributed
# 			in ADP(adposition) prep(prepositional modifier) increase
# 			the DET(determiner) det(determiner) use
# 			use NOUN(noun) pobj(object of preposition) in
# 			of ADP(adposition) prep(prepositional modifier) use
# 			smart ADJ(adjective) amod(adjectival modifier) devices
# 			devices NOUN(noun) pobj(object of preposition) of
# 			. PUNCT(punctuation) punct(punctuation) attributed
#
# ====================
#
# sentence:
# 	Smartphones have also increased the demand for mobile commerce platforms, such as the customized CoverGirl app.
# 		Sentence Parts:
# 			Smartphones NOUN(noun) nsubj(nominal subject) increased
# 			have AUX(auxiliary) aux(auxiliary) increased
# 			also ADV(adverb) advmod(adverbial modifier) increased
# 			increased VERB(verb) ROOT(root) increased
# 			the DET(determiner) det(determiner) demand
# 			demand NOUN(noun) dobj(direct object) increased
# 			for ADP(adposition) prep(prepositional modifier) demand
# 			mobile ADJ(adjective) amod(adjectival modifier) commerce
# 			commerce NOUN(noun) compound(compound) platforms
# 			platforms NOUN(noun) pobj(object of preposition) for
# 			, PUNCT(punctuation) punct(punctuation) platforms
# 			such ADJ(adjective) amod(adjectival modifier) as
# 			as ADP(adposition) prep(prepositional modifier) platforms
# 			the DET(determiner) det(determiner) app
# 			customized VERB(verb) amod(adjectival modifier) app
# 			CoverGirl PROPN(proper noun) compound(compound) app
# 			app NOUN(noun) pobj(object of preposition) as
# 			. PUNCT(punctuation) punct(punctuation) increased
#
# ====================
#
# sentence:
# 	The app employs predictive analytics software and applies real-time data to deliver personalized experiences to customers based on their preferences.
#
#
# 		Sentence Parts:
# 			The DET(determiner) det(determiner) app
# 			app NOUN(noun) nsubj(nominal subject) employs
# 			employs VERB(verb) ROOT(root) employs
# 			predictive ADJ(adjective) amod(adjectival modifier) software
# 			analytics NOUN(noun) compound(compound) software
# 			software NOUN(noun) dobj(direct object) employs
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) employs
# 			applies VERB(verb) conj(conjunct) employs
# 			real ADJ(adjective) amod(adjectival modifier) time
# 			- PUNCT(punctuation) punct(punctuation) time
# ...
# 			authorities NOUN(noun) nsubj(nominal subject) bolstered
# 			bolstered VERB(verb) ROOT(root) bolstered
# 			public ADJ(adjective) amod(adjectival modifier) confidence
# 			confidence NOUN(noun) dobj(direct object) bolstered
# 			in ADP(adposition) prep(prepositional modifier) confidence
# 			AI PROPN(proper noun) npadvmod(noun phrase as adverbial modifier) based
# 			- PUNCT(punctuation) punct(punctuation) based
# 			based VERB(verb) amod(adjectival modifier) systems
# 			systems NOUN(noun) pobj(object of preposition) in
# 			by ADP(adposition) prep(prepositional modifier) bolstered
# 			setting VERB(verb) pcomp(complement of preposition) by
# 			rules NOUN(noun) dobj(direct object) setting
# 			for ADP(adposition) prep(prepositional modifier) setting
# 			their PRON(pronoun) poss(possession modifier) development
# 			development NOUN(noun) pobj(object of preposition) for
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) development
# 			real ADJ(adjective) amod(adjectival modifier) world
# 			- PUNCT(punctuation) punct(punctuation) world
# 			world NOUN(noun) compound(compound) use
# 			use NOUN(noun) conj(conjunct) development
# 			across ADP(adposition) prep(prepositional modifier) setting
# 			various ADJ(adjective) amod(adjectival modifier) industries
# 			industries NOUN(noun) pobj(object of preposition) across
# 			. PUNCT(punctuation) punct(punctuation) bolstered
#
#
#  SPACE(space) dep(unclassified dependent) .
#
# ====================
#
# sentence:
# 	As such, North America is expected to hold the largest share of the AI market during the coming years.
# 		Sentence Parts:
# 			As ADP(adposition) prep(prepositional modifier) expected
# 			such ADJ(adjective) amod(adjectival modifier) As
# 			, PUNCT(punctuation) punct(punctuation) expected
# 			North PROPN(proper noun) compound(compound) America
# 			America PROPN(proper noun) nsubjpass(nominal subject (passive)) expected
# 			is AUX(auxiliary) auxpass(auxiliary (passive)) expected
# 			expected VERB(verb) ROOT(root) expected
# 			to PART(particle) aux(auxiliary) hold
# 			hold VERB(verb) xcomp(open clausal complement) expected
# 			the DET(determiner) det(determiner) share
# 			largest ADJ(adjective) amod(adjectival modifier) share
# 			share NOUN(noun) dobj(direct object) hold
# 			of ADP(adposition) prep(prepositional modifier) share
# 			the DET(determiner) det(determiner) market
# 			AI PROPN(proper noun) compound(compound) market
# 			market NOUN(noun) pobj(object of preposition) of
# 			during ADP(adposition) prep(prepositional modifier) hold
# 			the DET(determiner) det(determiner) years
# 			coming VERB(verb) amod(adjectival modifier) years
# 			years NOUN(noun) pobj(object of preposition) during
# 			. PUNCT(punctuation) punct(punctuation) expected
#
# ====================
#
# sentence:
# 	North America is home to several technology companies and has a strong network of research and development centers in this domain.
# 		Sentence Parts:
# 			North PROPN(proper noun) compound(compound) America
# 			America PROPN(proper noun) nsubj(nominal subject) is
# 			is AUX(auxiliary) ROOT(root) is
# 			home ADV(adverb) advmod(adverbial modifier) is
# 			to ADP(adposition) prep(prepositional modifier) home
# 			several ADJ(adjective) amod(adjectival modifier) companies
# 			technology NOUN(noun) compound(compound) companies
# 			companies NOUN(noun) pobj(object of preposition) to
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) is
# 			has VERB(verb) conj(conjunct) is
# 			a DET(determiner) det(determiner) network
# 			strong ADJ(adjective) amod(adjectival modifier) network
# 			network NOUN(noun) dobj(direct object) has
# 			of ADP(adposition) prep(prepositional modifier) network
# 			research NOUN(noun) nmod(modifier of nominal) centers
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) research
# 			development NOUN(noun) conj(conjunct) research
# 			centers NOUN(noun) pobj(object of preposition) of
# 			in ADP(adposition) prep(prepositional modifier) network
# 			this DET(determiner) det(determiner) domain
# 			domain NOUN(noun) pobj(object of preposition) in
# 			. PUNCT(punctuation) punct(punctuation) is
#
# ====================
#
# sentence:
# 	The U.S., Canada, and Mexico are major markets for AI-based services and technologies.
# 		Sentence Parts:
# 			The DET(determiner) det(determiner) U.S.
# 			U.S. PROPN(proper noun) nsubj(nominal subject) are
# 			, PUNCT(punctuation) punct(punctuation) U.S.
# 			Canada PROPN(proper noun) appos(appositional modifier) U.S.
# 			, PUNCT(punctuation) punct(punctuation) Canada
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) Canada
# 			Mexico PROPN(proper noun) conj(conjunct) Canada
# 			are AUX(auxiliary) ROOT(root) are
# 			major ADJ(adjective) amod(adjectival modifier) markets
# 			markets NOUN(noun) attr(attribute) are
# 			for ADP(adposition) prep(prepositional modifier) markets
# 			AI PROPN(proper noun) npadvmod(noun phrase as adverbial modifier) based
# 			- PUNCT(punctuation) punct(punctuation) based
# 			based VERB(verb) amod(adjectival modifier) services
# 			services NOUN(noun) pobj(object of preposition) for
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) services
# 			technologies NOUN(noun) conj(conjunct) services
# 			. PUNCT(punctuation) punct(punctuation) are
#
# ====================
#
# sentence:
# 	Furthermore, North America accounts for many global venture capital investments in AI startups, which indicates its growing adoption rate by businesses worldwide.
#
#
# 		Sentence Parts:
# 			Furthermore ADV(adverb) advmod(adverbial modifier) accounts
# 			, PUNCT(punctuation) punct(punctuation) accounts
# 			North PROPN(proper noun) compound(compound) America
# 			America PROPN(proper noun) nsubj(nominal subject) accounts
# 			accounts VERB(verb) ROOT(root) accounts
# 			for ADP(adposition) prep(prepositional modifier) accounts
# 			many ADJ(adjective) amod(adjectival modifier) investments
# 			global ADJ(adjective) amod(adjectival modifier) venture
# 			venture NOUN(noun) compound(compound) capital
# 			capital NOUN(noun) compound(compound) investments
# 			investments NOUN(noun) pobj(object of preposition) for
# 			in ADP(adposition) prep(prepositional modifier) investments
# 			AI PROPN(proper noun) compound(compound) startups
# 			startups NOUN(noun) pobj(object of preposition) in
# 			, PUNCT(punctuation) punct(punctuation) startups
# 			which PRON(pronoun) nsubj(nominal subject) indicates
# 			indicates VERB(verb) relcl(relative clause modifier) startups
# 			its PRON(pronoun) poss(possession modifier) rate
# 			growing VERB(verb) amod(adjectival modifier) rate
# 			adoption NOUN(noun) compound(compound) rate
# 			rate NOUN(noun) dobj(direct object) indicates
# 			by ADP(adposition) prep(prepositional modifier) rate
# 			businesses NOUN(noun) pobj(object of preposition) by
# 			worldwide ADV(adverb) advmod(adverbial modifier) indicates
# 			. PUNCT(punctuation) punct(punctuation) accounts
#
#
#  SPACE(space) dep(unclassified dependent) .
#
# ====================
#
# sentence:
# 	In Asia and the Pacific, the market is expected to grow at a substantial CAGR over the next few years.
# 		Sentence Parts:
# 			In ADP(adposition) prep(prepositional modifier) expected
# 			Asia PROPN(proper noun) pobj(object of preposition) In
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) Asia
# 			the DET(determiner) det(determiner) Pacific
# 			Pacific PROPN(proper noun) conj(conjunct) Asia
# 			, PUNCT(punctuation) punct(punctuation) expected
# 			the DET(determiner) det(determiner) market
# 			market NOUN(noun) nsubjpass(nominal subject (passive)) expected
# 			is AUX(auxiliary) auxpass(auxiliary (passive)) expected
# 			expected VERB(verb) ROOT(root) expected
# 			to PART(particle) aux(auxiliary) grow
# 			grow VERB(verb) xcomp(open clausal complement) expected
# 			at ADP(adposition) prep(prepositional modifier) grow
# 			a DET(determiner) det(determiner) CAGR
# 			substantial ADJ(adjective) amod(adjectival modifier) CAGR
# 			CAGR NOUN(noun) pobj(object of preposition) at
# 			over ADP(adposition) prep(prepositional modifier) grow
# 			the DET(determiner) det(determiner) years
# 			next ADJ(adjective) amod(adjectival modifier) years
# 			few ADJ(adjective) amod(adjectival modifier) years
# 			years NOUN(noun) pobj(object of preposition) over
# 			. PUNCT(punctuation) punct(punctuation) expected
#
# ====================
#
# sentence:
# 	This expansion is attributable to the increased investments in artificial intelligence.
# 		Sentence Parts:
# 			This DET(determiner) det(determiner) expansion
# 			expansion NOUN(noun) nsubj(nominal subject) is
# 			is AUX(auxiliary) ROOT(root) is
# 			attributable ADJ(adjective) acomp(adjectival complement) is
# 			to ADP(adposition) prep(prepositional modifier) attributable
# 			the DET(determiner) det(determiner) investments
# 			increased VERB(verb) amod(adjectival modifier) investments
# 			investments NOUN(noun) pobj(object of preposition) to
# 			in ADP(adposition) prep(prepositional modifier) investments
# 			artificial ADJ(adjective) amod(adjectival modifier) intelligence
# 			intelligence NOUN(noun) pobj(object of preposition) in
# 			. PUNCT(punctuation) punct(punctuation) is
#
# ====================
#
# sentence:
# 	For example, Baidu, Inc., a Chinese Internet behemoth, stated in April 2018 that it had entered into definitive agreements with investors about the sale of its financial services group, which provides wealth management, consumer lending, and other commercial services.
# 		Sentence Parts:
# 			For ADP(adposition) prep(prepositional modifier) stated
# 			example NOUN(noun) pobj(object of preposition) For
# 			, PUNCT(punctuation) punct(punctuation) stated
# 			Baidu PROPN(proper noun) nmod(modifier of nominal) Inc.
# 			, PUNCT(punctuation) punct(punctuation) Inc.
# 			Inc. PROPN(proper noun) nsubj(nominal subject) stated
# 			, PUNCT(punctuation) punct(punctuation) Inc.
# 			a DET(determiner) det(determiner) behemoth
# 			Chinese ADJ(adjective) amod(adjectival modifier) behemoth
# 			Internet PROPN(proper noun) compound(compound) behemoth
# 			behemoth NOUN(noun) appos(appositional modifier) Inc.
# 			, PUNCT(punctuation) punct(punctuation) Inc.
# 			stated VERB(verb) ROOT(root) stated
# 			in ADP(adposition) prep(prepositional modifier) stated
# 			April PROPN(proper noun) pobj(object of preposition) in
# 			2018 NUM(numeral) nummod(numeric modifier) April
# 			that SCONJ(subordinating conjunction) mark(marker) entered
# 			it PRON(pronoun) nsubj(nominal subject) entered
# 			had AUX(auxiliary) aux(auxiliary) entered
# 			entered VERB(verb) ccomp(clausal complement) stated
# 			into ADP(adposition) prep(prepositional modifier) entered
# 			definitive ADJ(adjective) amod(adjectival modifier) agreements
# 			agreements NOUN(noun) pobj(object of preposition) into
# 			with ADP(adposition) prep(prepositional modifier) agreements
# 			investors NOUN(noun) pobj(object of preposition) with
# 			about ADP(adposition) prep(prepositional modifier) agreements
# 			the DET(determiner) det(determiner) sale
# 			sale NOUN(noun) pobj(object of preposition) about
# 			of ADP(adposition) prep(prepositional modifier) sale
# 			its PRON(pronoun) poss(possession modifier) group
# 			financial ADJ(adjective) amod(adjectival modifier) services
# 			services NOUN(noun) compound(compound) group
# 			group NOUN(noun) pobj(object of preposition) of
# 			, PUNCT(punctuation) punct(punctuation) group
# 			which PRON(pronoun) nsubj(nominal subject) provides
# 			provides VERB(verb) relcl(relative clause modifier) group
# 			wealth NOUN(noun) compound(compound) management
# 			management NOUN(noun) dobj(direct object) provides
# 			, PUNCT(punctuation) punct(punctuation) management
# 			consumer NOUN(noun) compound(compound) lending
# 			lending NOUN(noun) conj(conjunct) management
# 			, PUNCT(punctuation) punct(punctuation) lending
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) lending
# 			other ADJ(adjective) amod(adjectival modifier) services
# 			commercial ADJ(adjective) amod(adjectival modifier) services
# 			services NOUN(noun) conj(conjunct) lending
# 			. PUNCT(punctuation) punct(punctuation) stated
#
# ====================
#
# sentence:
# 	In addition, the increasing number of AI startups in the region is accelerating the implementation of AI to enhance operational efficiency and enable process automation.
#
#
# 		Sentence Parts:
# 			In ADP(adposition) prep(prepositional modifier) accelerating
# 			addition NOUN(noun) pobj(object of preposition) In
# 			, PUNCT(punctuation) punct(punctuation) accelerating
# 			the DET(determiner) det(determiner) number
# 			increasing VERB(verb) amod(adjectival modifier) number
# 			number NOUN(noun) nsubj(nominal subject) accelerating
# 			of ADP(adposition) prep(prepositional modifier) number
# 			AI PROPN(proper noun) compound(compound) startups
# 			startups NOUN(noun) pobj(object of preposition) of
# 			in ADP(adposition) prep(prepositional modifier) startups
# 			the DET(determiner) det(determiner) region
# 			region NOUN(noun) pobj(object of preposition) in
# 			is AUX(auxiliary) aux(auxiliary) accelerating
# 			accelerating VERB(verb) ROOT(root) accelerating
# 			the DET(determiner) det(determiner) implementation
# 			implementation NOUN(noun) dobj(direct object) accelerating
# 			of ADP(adposition) prep(prepositional modifier) implementation
# 			AI PROPN(proper noun) pobj(object of preposition) of
# 			to PART(particle) aux(auxiliary) enhance
# 			enhance VERB(verb) advcl(adverbial clause modifier) accelerating
# 			operational ADJ(adjective) amod(adjectival modifier) efficiency
# 			efficiency NOUN(noun) dobj(direct object) enhance
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) efficiency
# 			enable VERB(verb) amod(adjectival modifier) automation
# 			process NOUN(noun) compound(compound) automation
# 			automation NOUN(noun) conj(conjunct) efficiency
# 			. PUNCT(punctuation) punct(punctuation) accelerating
#
#
#  SPACE(space) dep(unclassified dependent) .
#
# ====================
#
# sentence:
# 	​​Additionally, the region is expected to continue growing in the healthcare, manufacturing, finance, and retail sectors.
# 		Sentence Parts:
# 			​​Additionally ADV(adverb) advmod(adverbial modifier) expected
# 			, PUNCT(punctuation) punct(punctuation) expected
# 			the DET(determiner) det(determiner) region
# 			region NOUN(noun) nsubjpass(nominal subject (passive)) expected
# 			is AUX(auxiliary) auxpass(auxiliary (passive)) expected
# 			expected VERB(verb) ROOT(root) expected
# 			to PART(particle) aux(auxiliary) continue
# 			continue VERB(verb) xcomp(open clausal complement) expected
# 			growing VERB(verb) xcomp(open clausal complement) continue
# 			in ADP(adposition) prep(prepositional modifier) growing
# 			the DET(determiner) det(determiner) healthcare
# 			healthcare NOUN(noun) pobj(object of preposition) in
# 			, PUNCT(punctuation) punct(punctuation) healthcare
# 			manufacturing NOUN(noun) conj(conjunct) healthcare
# 			, PUNCT(punctuation) punct(punctuation) manufacturing
# 			finance NOUN(noun) conj(conjunct) manufacturing
# 			, PUNCT(punctuation) punct(punctuation) finance
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) finance
# 			retail ADJ(adjective) amod(adjectival modifier) sectors
# 			sectors NOUN(noun) conj(conjunct) finance
# 			. PUNCT(punctuation) punct(punctuation) expected
#
# ====================
#
# sentence:
# 	This is due to increased revenue generated from the sale of AI products and
# 		Sentence Parts:
# 			This PRON(pronoun) nsubj(nominal subject) is
# 			is AUX(auxiliary) ROOT(root) is
# 			due ADJ(adjective) acomp(adjectival complement) is
# 			to ADP(adposition) prep(prepositional modifier) due
# 			increased VERB(verb) amod(adjectival modifier) revenue
# 			revenue NOUN(noun) pobj(object of preposition) to
# 			generated VERB(verb) acl(clausal modifier of noun (adjectival clause)) revenue
# 			from ADP(adposition) prep(prepositional modifier) generated
# 			the DET(determiner) det(determiner) sale
# 			sale NOUN(noun) pobj(object of preposition) from
# 			of ADP(adposition) prep(prepositional modifier) sale
# 			AI PROPN(proper noun) compound(compound) products
# 			products NOUN(noun) pobj(object of preposition) of
# 			and CCONJ(coordinating conjunction) cc(coordinating conjunction) is
#
# ====================

# %%
analyser.named_entities()
# Out:
#                          TEXT    LABEL
# 0               $93.5 billion    MONEY
# 1                        2021     DATE
# 2   Grand View Research, Inc.      ORG
# 3                      annual     DATE
# 4                       38.1%  PERCENT
# ..                        ...      ...
# 92                    Chinese     NORP
# 93                 April 2018     DATE
# 94                         AI      GPE
# 95                         AI      GPE
# 96                         AI      ORG
#
# [97 rows x 2 columns]

# %%
analyser.find_matches([{"TEXT": "Artificial"}, {"TEXT": "Intelligence"}])
# Out:
#                    MATCHES
# 0  Artificial Intelligence
# 1  Artificial Intelligence
# 2  Artificial Intelligence
# 3  Artificial Intelligence

# %%
analyser.find_matches([{"TEXT": "AI"}, {"POS": "VERB"}])
# Out:
#    MATCHES
# 0  AI grew

# %%
analyser.find_matches([{"IS_DIGIT": True}, {"TEXT": "%"}])
# Out:
#   MATCHES
# 0     66%
# 1    115%
# 2     42%

# %%
analyser.find_matches([
    {"IS_TITLE": True, "POS": "PROPN", "TEXT": {"NOT_IN": ["India", "Pune", "Sept.", "Artificial", "Intelligence"]}},
    {"IS_TITLE": True, "POS": "PROPN", "OP": "?"},
    {"LOWER": {"IN": ["Inc", "LLC", "Ltd", "Corporation", "Corp", "Co"]}, "OP": "?"}
])
# Out:
#           MATCHES
# 0           Grand
# 1            View
# 2      Grand View
# 3        Research
# 4   View Research
# ..            ...
# 87        Pacific
# 88          Baidu
# 89           Inc.
# 90       Internet
# 91          April
#
# [92 rows x 1 columns]
